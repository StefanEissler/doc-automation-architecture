# %% [markdown]
# # Vorbereitung des Experiment
#
# Aufbereitung der Daten für den ersten Experimentendurchlauf. Gestützt auf das Dataset vrdu ad-buy-form Korpus zur internen Vergleichbarkeit der Experimentbedingungen in einer Domäne.

# %%
import os

RAW_DATA_PATH = "../data/raw/vrdu/ad-buy-form/"
OUTPUT_DIR = "../data/processed/"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# %%
import pandas as pd

df_ad_buy_form = pd.read_json(
    "../data/raw/vrdu/ad-buy-form/main/dataset.jsonl", lines=True
)

df_ad_buy_form.head(5)
# Out:
#                                    filename  \
# 0  00a83bbc-0101-f092-4bd7-e75f315e8f14.pdf
# 1  00c29ad8-c88b-b3bb-1a39-3267e47c7a88.pdf
# 2  00c3353e-a25f-574a-a9db-39a41579895a.pdf
# 3  01250d60-2a0a-0c93-5a18-9f1f195fdc1a.pdf
# 4  0179ed96-6b64-eb8b-07c1-3214262dec0c.pdf
#
#                                          file_path  \
# 0  ./pdfs/00a83bbc-0101-f092-4bd7-e75f315e8f14.pdf
# 1  ./pdfs/00c29ad8-c88b-b3bb-1a39-3267e47c7a88.pdf
# 2  ./pdfs/00c3353e-a25f-574a-a9db-39a41579895a.pdf
# 3  ./pdfs/01250d60-2a0a-0c93-5a18-9f1f195fdc1a.pdf
# 4  ./pdfs/0179ed96-6b64-eb8b-07c1-3214262dec0c.pdf
#
#                                                  ocr  \
# 0  {'text': 'Page 1 of 2
# INVOICE
# FOX
# Remit Addres...
# 1  {'text': 'Page 1 of 1
# INVOICE
# DUE ATE
# 2436316-...
# 2  {'text': 'Print Date 02/28/20 14:21:20
# Page 1 ...
# 3  {'text': 'Page 1 of 4
# INVOICE
# Advertiser
# 4
# Rem...
# 4  {'text': 'Contract #
# Date Entered
# Schedule Dat...
#
#                                          annotations
# 0  [[property, [['KMSP\n', [0, 0.14883721, 0.0662...
# 1  [[property, [['WXXA\n', [0, 0.14763948, 0.0677...
# 2  [[contract_num, [['14086\n', [0, 0.27917981000...
# 3  [[property, [['KCNC-TV\n', [0, 0.14883721, 0.0...
# 4  [[contract_num, [['575746\n', [0, 0.3472609200...

# %% [markdown]
# ### Auslesen der Annotationen

# %%
ad_buy_meta = pd.read_json("../data/raw/vrdu/ad-buy-form/main/meta.json")

line_items_df = ad_buy_meta[ad_buy_meta["entity_appearance_pattern"] == "line_item"]

line_item_keys = line_items_df.index.tolist()

line_item_keys
# Out:
# ['channel',
#  'program_desc',
#  'program_start_date',
#  'program_end_date',
#  'sub_amount']

# %%
import pandas as pd

def extract_clean_text(data):
    if isinstance(data, str):
        return data.replace("\n", " ").strip()
    elif isinstance(data, list):
        texts = []
        for item in data:
            # Bounding-Boxen überspringen (Listen, die mit Zahlen beginnen)
            if (
                isinstance(item, list)
                and len(item) > 0
                and isinstance(item[0], (int, float))
            ):
                continue
            extracted = extract_clean_text(item)
            if extracted:
                texts.append(extracted)
        return " ".join(texts)
    return ""


def create_vrdu_dataframe(df_input):
    processed_docs = []

    for doc in df_input.to_dict(orient="records"):
        annotations_list = doc.get("annotations", [])
        ground_truth = {}
        line_items_extracted = []

        if isinstance(annotations_list, list):
            for annotation in annotations_list:
                if not isinstance(annotation, list) or len(annotation) < 2:
                    continue

                entity_keys = annotation[0]
                entity_values = annotation[1]

                if isinstance(entity_keys, str):
                    field_name = entity_keys
                    clean_value = extract_clean_text(entity_values)

                    if field_name in ground_truth and ground_truth[field_name]:
                        ground_truth[field_name] += " " + clean_value
                    else:
                        ground_truth[field_name] = clean_value

                elif isinstance(entity_keys, list):
                    headers = entity_keys
                    rows = entity_values

                    if isinstance(rows, list):
                        for row in rows:
                            row_dict = {}
                            if isinstance(row, list):
                                for idx, header in enumerate(headers):
                                    if idx < len(row):
                                        row_dict[header] = extract_clean_text(row[idx])
                                line_items_extracted.append(row_dict)

        if line_items_extracted:
            ground_truth["line_items"] = line_items_extracted
            has_line_items = True
        else:
            has_line_items = False

        property_clean = ground_truth.get("property", "UNKNOWN")

        processed_docs.append(
            {
                "doc_id": doc.get("filename", "unknown_id"),
                "property": property_clean,
                "has_line_items": has_line_items,
                "ground_truth": ground_truth,
                "raw_doc": doc,
                "annotations": annotations_list,
                "ocr_text": extract_clean_text(doc.get("ocr", {}).get("text", "")),
            }
        )

    return pd.DataFrame(processed_docs)

df_processed = create_vrdu_dataframe(df_ad_buy_form)

# %%
df_processed.head(5)
# Out:
#                                      doc_id  \
# 0  00a83bbc-0101-f092-4bd7-e75f315e8f14.pdf
# 1  00c29ad8-c88b-b3bb-1a39-3267e47c7a88.pdf
# 2  00c3353e-a25f-574a-a9db-39a41579895a.pdf
# 3  01250d60-2a0a-0c93-5a18-9f1f195fdc1a.pdf
# 4  0179ed96-6b64-eb8b-07c1-3214262dec0c.pdf
#
#                                             property  has_line_items  \
# 0                                KMSP KMSP KMSP KMSP            True
# 1                                          WXXA WXXA            True
# 2                                            WSIL-TV            True
# 3  KCNC-TV KCNC-TV KCNC-TV KCNC-TV KCNC-TV KCNC-T...            True
# 4                                KBJR Television Inc            True
#
#                                         ground_truth  \
# 0  {'property': 'KMSP KMSP KMSP KMSP', 'tv_addres...
# 1  {'property': 'WXXA WXXA', 'tv_address': 'PO Bo...
# 2  {'contract_num': '14086', 'product': 'Mike Car...
# 3  {'property': 'KCNC-TV KCNC-TV KCNC-TV KCNC-TV ...
# 4  {'contract_num': '575746', 'flight_from': '05/...
#
#                                              raw_doc  \
# 0  {'filename': '00a83bbc-0101-f092-4bd7-e75f315e...
# 1  {'filename': '00c29ad8-c88b-b3bb-1a39-3267e47c...
# 2  {'filename': '00c3353e-a25f-574a-a9db-39a41579...
# 3  {'filename': '01250d60-2a0a-0c93-5a18-9f1f195f...
# 4  {'filename': '0179ed96-6b64-eb8b-07c1-3214262d...
#
#                                          annotations  \
# 0  [[property, [['KMSP\n', [0, 0.14883721, 0.0662...
# 1  [[property, [['WXXA\n', [0, 0.14763948, 0.0677...
# 2  [[contract_num, [['14086\n', [0, 0.27917981000...
# 3  [[property, [['KCNC-TV\n', [0, 0.14883721, 0.0...
# 4  [[contract_num, [['575746\n', [0, 0.3472609200...
#
#                                             ocr_text
# 0  Page 1 of 2 INVOICE FOX Remit Address: KMSP 46...
# 1  Page 1 of 1 INVOICE DUE ATE 2436316-1 POL/FWD....
# 2  Print Date 02/28/20 14:21:20 Page 1 of 1 ORDER...
# 3  Page 1 of 4 INVOICE Advertiser 4 Remit Address...
# 4  Contract # Date Entered Schedule Dates Last Mo...

# %%
def count_annotation_spans(annotations_list):
    """
    Zählt die Gesamtanzahl aller annotierten Werteinstanzen in einem Dokument.
    - Flat fields: zählt jeden OCR-Span
    - Line items:  zählt jede Tabellenzeile
    """
    if not isinstance(annotations_list, list):
        return 0
    count = 0
    for ann in annotations_list:
        if not isinstance(ann, list) or len(ann) < 2:
            continue
        if isinstance(ann[0], str):  # Flat field
            count += len(ann[1]) if isinstance(ann[1], list) else 1
        elif isinstance(ann[0], list):  # Line item (Hierarchical)
            count += len(ann[1]) if isinstance(ann[1], list) else 1
    return count


df_processed["annotation_count"] = df_processed["raw_doc"].apply(
    lambda doc: count_annotation_spans(doc.get("annotations", []))
)

# Terzile berechnen
p33 = df_processed["annotation_count"].quantile(0.33)
p66 = df_processed["annotation_count"].quantile(0.66)

df_processed["complexity"] = df_processed["annotation_count"].apply(
    lambda c: "L1" if c <= p33 else ("L2" if c <= p66 else "L3")
)

print(df_processed["complexity"].value_counts())
print(f"\nTerzilgrenzen: L1 ≤ {p33:.0f}, L2 ≤ {p66:.0f}, L3 > {p66:.0f}")
print(df_processed.groupby("complexity")["annotation_count"].describe())
# Out:
# complexity
# L1    224
# L3    210
# L2    207
# Name: count, dtype: int64
#
# Terzilgrenzen: L1 ≤ 19, L2 ≤ 34, L3 > 34
#             count       mean        std   min   25%   50%    75%    max
# complexity
# L1          224.0  12.915179   3.259610   1.0  11.0  12.0  15.00   19.0
# L2          207.0  26.888889   4.186458  20.0  23.5  27.0  30.00   34.0
# L3          210.0  51.214286  17.125397  35.0  39.0  48.0  56.75  154.0

# %% [markdown]
# # Auswertung des Splits

# %%
df_processed.has_line_items.groupby(df_processed.complexity).value_counts()
# Out:
# complexity  has_line_items
# L1          True              219
#             False               5
# L2          True              207
# L3          True              210
# Name: count, dtype: int64

# %% [markdown]
# Fast alle Dokumente bis auf 5 in L1 enthalten auch Tabellarische Daten und sind somit nicht für die Einteilung in Komplexitätsstufen geeignet.

# %%
def calculate_text_metrics(text):
    """Berechnet Wortanzahl und Zeichenanzahl aus dem OCR-Text."""

    if not isinstance(text, str):
        return {"word_count": 0, "char_count": 0}

    words = text.split()
    return {"word_count": len(words), "char_count": len(text)}

metrics_df = df_processed["ocr_text"].apply(calculate_text_metrics).apply(pd.Series)
df_processed = pd.concat([df_processed, metrics_df], axis=1)

print("\n Durchschnittliche Wortanzahl (Word Count) pro Komplexität")
print(df_processed.groupby("complexity")["word_count"].describe())
# Out:
#  Durchschnittliche Wortanzahl (Word Count) pro Komplexität
#             count         mean          std    min     25%     50%      75%  \
# complexity
# L1          224.0   645.616071  1009.409366   90.0   266.0   334.5   483.75
# L2          207.0  1164.975845  1093.281999  347.0   613.0   776.0  1219.00
# L3          210.0  1764.752381  1265.812437  618.0  1089.0  1315.5  1788.00
#
#                 max
# complexity
# L1          10393.0
# L2          11057.0
# L3          11519.0

# %%
print("\nDurchschnittliche Zeichenanzahl (Char Count) pro Komplexität")
print(df_processed.groupby("complexity")["char_count"].describe())
# Out:
# Durchschnittliche Zeichenanzahl (Char Count) pro Komplexität
#             count          mean          std     min     25%     50%  \
# complexity
# L1          224.0   4092.437500  6528.550934   644.0  1707.5  2156.0
# L2          207.0   7243.386473  7082.858816  2414.0  3675.0  4750.0
# L3          210.0  10936.261905  8222.364767  3941.0  6438.0  8073.0
#
#                  75%      max
# complexity
# L1           3143.25  68923.0
# L2           7512.50  72947.0
# L3          11217.25  75843.0

# %%
df_processed.head(5)
# Out:
#                                      doc_id  \
# 0  00a83bbc-0101-f092-4bd7-e75f315e8f14.pdf
# 1  00c29ad8-c88b-b3bb-1a39-3267e47c7a88.pdf
# 2  00c3353e-a25f-574a-a9db-39a41579895a.pdf
# 3  01250d60-2a0a-0c93-5a18-9f1f195fdc1a.pdf
# 4  0179ed96-6b64-eb8b-07c1-3214262dec0c.pdf
#
#                                             property  has_line_items  \
# 0                                KMSP KMSP KMSP KMSP            True
# 1                                          WXXA WXXA            True
# 2                                            WSIL-TV            True
# 3  KCNC-TV KCNC-TV KCNC-TV KCNC-TV KCNC-TV KCNC-T...            True
# 4                                KBJR Television Inc            True
#
#                                         ground_truth  \
# 0  {'property': 'KMSP KMSP KMSP KMSP', 'tv_addres...
# 1  {'property': 'WXXA WXXA', 'tv_address': 'PO Bo...
# 2  {'contract_num': '14086', 'product': 'Mike Car...
# 3  {'property': 'KCNC-TV KCNC-TV KCNC-TV KCNC-TV ...
# 4  {'contract_num': '575746', 'flight_from': '05/...
#
#                                              raw_doc  \
# 0  {'filename': '00a83bbc-0101-f092-4bd7-e75f315e...
# 1  {'filename': '00c29ad8-c88b-b3bb-1a39-3267e47c...
# 2  {'filename': '00c3353e-a25f-574a-a9db-39a41579...
# 3  {'filename': '01250d60-2a0a-0c93-5a18-9f1f195f...
# 4  {'filename': '0179ed96-6b64-eb8b-07c1-3214262d...
#
#                                          annotations  \
# 0  [[property, [['KMSP\n', [0, 0.14883721, 0.0662...
# 1  [[property, [['WXXA\n', [0, 0.14763948, 0.0677...
# 2  [[contract_num, [['14086\n', [0, 0.27917981000...
# 3  [[property, [['KCNC-TV\n', [0, 0.14883721, 0.0...
# 4  [[contract_num, [['575746\n', [0, 0.3472609200...
#
#                                             ocr_text  annotation_count  \
# 0  Page 1 of 2 INVOICE FOX Remit Address: KMSP 46...                25
# 1  Page 1 of 1 INVOICE DUE ATE 2436316-1 POL/FWD....                11
# 2  Print Date 02/28/20 14:21:20 Page 1 of 1 ORDER...                11
# 3  Page 1 of 4 INVOICE Advertiser 4 Remit Address...                51
# 4  Contract # Date Entered Schedule Dates Last Mo...                18
#
#   complexity  word_count  char_count
# 0         L2         739        4524
# 1         L1         200        1260
# 2         L1         241        1506
# 3         L3        1117        6723
# 4         L1         385        2348

# %% [markdown]
# Über die 3 Schwierigkeitsstufen zeigt sich ein Anstieg der Informationsdichte. Dies kann über die ansteigende Zeichen und Wortdichte erfasst werden, sowie durch den höheren Anteil an Annoatationen, die im Experiment extrahiert werden.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

grouped_means = (
    df_processed.groupby("complexity")[["annotation_count", "word_count", "char_count"]]
    .mean()
    .reset_index()
)

grouped_means["complexity"] = pd.Categorical(
    grouped_means["complexity"], categories=["L1", "L2", "L3"], ordered=True
)
grouped_means = grouped_means.sort_values("complexity")

sns.set_theme(style="whitegrid", context="paper")

fig, axes = plt.subplots(1, 3, figsize=(16, 5))
fig.suptitle(
    "Validierung der Dokumentenkomplexität Teilexperiment A (interne Validierung) (L1 - L3)",
    fontsize=16,
    fontweight="bold",
    y=1.05,
)

# Durchschnittliche Annotations
sns.barplot(
    ax=axes[0],
    data=grouped_means,
    x="complexity",
    y="annotation_count",
    hue="complexity",
    palette="Blues_d",
    legend=False,
    dodge=False,
)
axes[0].set_title("Durchschnittliche Informationsdichte", fontsize=12)
axes[0].set_ylabel("Anzahl Annotations", fontsize=11)
axes[0].set_xlabel("Komplexitätsstufe", fontsize=11)

for p in axes[0].patches:
    axes[0].annotate(
        format(p.get_height(), ".1f"),
        (p.get_x() + p.get_width() / 2.0, p.get_height()),
        ha="center",
        va="center",
        xytext=(0, 9),
        textcoords="offset points",
    )

# Durchschnittlicher Word Count
sns.barplot(
    ax=axes[1],
    data=grouped_means,
    x="complexity",
    y="word_count",
    hue="complexity",
    palette="Blues_d",
    legend=False,
    dodge=False,
)
axes[1].set_title("Durchschnittliche Wortanzahl", fontsize=12)
axes[1].set_ylabel("Words (OCR)", fontsize=11)
axes[1].set_xlabel("Komplexitätsstufe", fontsize=11)
for p in axes[1].patches:
    axes[1].annotate(
        format(p.get_height(), ".0f"),
        (p.get_x() + p.get_width() / 2.0, p.get_height()),
        ha="center",
        va="center",
        xytext=(0, 9),
        textcoords="offset points",
    )

# Durchschnittlicher Char Count
sns.barplot(
    ax=axes[2],
    data=grouped_means,
    x="complexity",
    y="char_count",
    hue="complexity",
    palette="Blues_d",
    legend=False,
    dodge=False,
)
axes[2].set_title("Durchschnittliche Zeichenanzahl", fontsize=12)
axes[2].set_ylabel("Characters (OCR)", fontsize=11)
axes[2].set_xlabel("Komplexitätsstufe", fontsize=11)
for p in axes[2].patches:
    axes[2].annotate(
        format(p.get_height(), ".0f"),
        (p.get_x() + p.get_width() / 2.0, p.get_height()),
        ha="center",
        va="center",
        xytext=(0, 9),
        textcoords="offset points",
    )

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Ziehung der Stichprobe

# %%
df_experiment = df_processed.groupby("complexity").sample(n=25, random_state=42)

df_experiment["complexity"] = pd.Categorical(
    df_experiment["complexity"], categories=["L1", "L2", "L3"], ordered=True
)

print(f"Finale Stichprobengröße für das Experiment: {len(df_experiment)}")
print(df_experiment["complexity"].value_counts())
# Out:
# Finale Stichprobengröße für das Experiment: 75
# complexity
# L1    25
# L2    25
# L3    25
# Name: count, dtype: int64

# %% [markdown]
# ## Statistische Auswertung der Stichprobenziehung

# %% [markdown]
# ### Verteilung der Daten

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(
    style="whitegrid", context="talk"
)

fig, axes = plt.subplots(
    1,
    2,
    figsize=(16, 9),
    constrained_layout=True,
)

fig.suptitle(
    f"Validierung der Stichprobe (N={len(df_experiment)}): Komplexitätsstufen (L1 - L3)",
    fontsize=22,
    fontweight="bold",
)

palette = "Blues_d"

sns.boxplot(
    ax=axes[0],
    data=df_experiment,
    x="complexity",
    y="annotation_count",
    hue="complexity",
    palette=palette,
    legend=False,
    showfliers=False,
)
axes[0].set_title("Annotation Count", fontsize=18, fontweight="bold", pad=15)
axes[0].set_xlabel("Complexity", fontsize=16)
axes[0].set_ylabel("Annotation Count", fontsize=16)
axes[0].tick_params(
    axis="both", labelsize=14
) 

sns.boxplot(
    ax=axes[1],
    data=df_experiment,
    x="complexity",
    y="word_count",
    hue="complexity",
    palette=palette,
    legend=False,
    showfliers=False,
)
axes[1].set_title("Word Count", fontsize=18, fontweight="bold", pad=15)
axes[1].set_xlabel("Complexity", fontsize=16)
axes[1].set_ylabel("Word Count", fontsize=16)
axes[1].tick_params(
    axis="both", labelsize=14
)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/6w/x9kzkbyn6r3_g6mbn02xl3740000gn/T/ipykernel_7228/1052667017.py:57: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
sns.set_theme(style="whitegrid", context="paper")
plt.figure(figsize=(8, 5))
sns.boxplot(
    data=df_experiment,
    x="complexity",
    y="char_count",
    hue="complexity",
    palette=palette,
    legend=False,
    boxprops={"alpha": 0.7, "edgecolor": "0.3"},
    showfliers=False,
)

plt.title(
    "Verteilung der Zeichenanzahl nach Komplexitätsstufe",
    fontsize=16,
    fontweight="bold",
    pad=15,
)
plt.xlabel("Komplexitätsstufe (Complexity)", fontsize=10)
plt.ylabel("Zeichenanzahl (Character Count)", fontsize=10)

plt.tight_layout()
plt.show()

# %% [markdown]
# Die Abbildung zeigt über die drei Merkmale einen konsistenten, monoton ansteigenden Trend über die Stufen L1 bis L3 auf. Vor allem durch die Unterscheidung der Dokumentenlängen wird dies deutlich. insbesondere L2 und L3 zeigen eine deutlich breitere Interquartilsspanne, was auf eine größere strukturelle Heterogenität dieser Dokumente hindeutet. Diese werden im folgenden genauer untersucht.

# %%
sns.set_theme(style="whitegrid", context="paper")
plt.figure(figsize=(10, 6))

# Der Violinplot zeigt die Form der Verteilung
sns.violinplot(
    data=df_experiment,
    x="complexity",
    y="annotation_count",
    palette=palette,
    inner="quartile", 
    alpha=0.5,
    order=["L1", "L2", "L3"],
)

# Der Stripplot legt die echten, einzelnen Datenpunkte darüber
sns.stripplot(
    data=df_experiment,
    x="complexity",
    y="annotation_count",
    color="black",
    alpha=0.6,  
    jitter=True,  
    size=5, 
    order=["L1", "L2", "L3"],
)

plt.title(
    "Verteilung der Annotation Counts nach Komplexitätsstufe",
    fontsize=16,
    fontweight="bold",
    pad=15,
)
plt.xlabel("Komplexitätsstufe", fontsize=12)
plt.ylabel("Anzahl Annotationen", fontsize=12)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/6w/x9kzkbyn6r3_g6mbn02xl3740000gn/T/ipykernel_7228/80039451.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(

# %% [markdown]
# Auf dem Plot ist zu sehen, dass L1 eine starke Ballung an seinem Mittel von 18 hat, während L2 höher liegt und eine nicht so starke Stauchung vorliet. In L3 ist eine sehr hohe Varianz zu erkennen, durch die starken Ausreiser bis größer als 140.

# %% [markdown]
# ### Untersuchung der Annotationen auf Normalverteilung

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as stats
import seaborn as sns
from IPython.display import display

l1_counts = df_experiment[df_experiment["complexity"] == "L1"]["annotation_count"]
l2_counts = df_experiment[df_experiment["complexity"] == "L2"]["annotation_count"]
l3_counts = df_experiment[df_experiment["complexity"] == "L3"]["annotation_count"]

data_dict = {"L1": l1_counts, "L2": l2_counts, "L3": l3_counts}

results = []

for level, data in data_dict.items():
    # Shapiro-Wilk-Test (H0: Daten sind normalverteilt)
    stat, p_value = stats.shapiro(data)

    # Signifikanz prüfen (alpha = 0.05)
    is_normal = "Ja" if p_value >= 0.05 else "Nein"

    results.append(
        {
            "Komplexitätsstufe": level,
            "N (Stichprobe)": len(data),
            "W-Statistik": round(stat, 4),
            "p-Wert": f"{p_value:.5e}",
            "Normalverteilt (α=0.05)?": is_normal,
        }
    )

df_shapiro = pd.DataFrame(results)

print("Shapiro-Wilk-Test auf Normalverteilung")

display(df_shapiro)
# Out:
# Shapiro-Wilk-Test auf Normalverteilung
#   Komplexitätsstufe  N (Stichprobe)  W-Statistik       p-Wert  \
# 0                L1              25       0.9597  4.07933e-01
# 1                L2              25       0.9521  2.79156e-01
# 2                L3              25       0.7147  1.15586e-05
#
#   Normalverteilt (α=0.05)?
# 0                       Ja
# 1                       Ja
# 2                     Nein

# %%
# Histogramm Plots mit theoretischer Normalverteilungskurve drüber
sns.set_theme(style="whitegrid", context="paper")


fig, axes = plt.subplots(3, 1, figsize=(14, 10))
fig.suptitle(
    "Visuelle Prüfung auf Normalverteilung (L1 - L3)",
    fontsize=16,
    fontweight="bold",
    y=1.02,
)

colors = ["green", "orange", "blue"]
colors = ["darkgreen", "darkorange", "darkblue"]

for i, (level, data) in enumerate(data_dict.items()):

    sns.histplot(
        data,
        kde=True,
        stat="density",
        ax=axes[i],
        color=colors[i],
        bins=15,
        line_kws={"linestyle": "-", "color": colors[i], "linewidth": 2},
    )
    axes[i].set_title(f"Histogramm {level}", fontweight="bold")
    axes[i].set_xlabel("Anzahl Annotationen")
    axes[i].set_ylabel("Dichte")

    # Theoretische Normalverteilungskurve drüberlegen
    xmin, xmax = axes[i].get_xlim()
    x = np.linspace(xmin, xmax, 100)
    p = stats.norm.pdf(x, data.mean(), data.std())
    axes[i].plot(
        x, p, "k", linewidth=2, linestyle="--", label="Theor. Normalverteilung"
    )
    axes[i].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Statistischer Test der Unterschiede zwischen Annotationen in den Gruppen

# %% [markdown]
# Da die Hypothese der Normalverteilung abgelehnt werden muss für L3, wird ein Kurskal Wallis Test angewendet, um die statisitsche Signifikanten Unterschiede zwischen den Gruppen zu beweisen, hinsichtlich des Aufwands durch viele Felder zur Extraktion.

# %%
import pandas as pd
import scikit_posthocs as sp
import scipy.stats as stats
from IPython.display import display

print("1. Kruskal-Wallis-Test (Globaler Unterschied)")

# Kruskal Wallist-Test mit stats berechnen
stat_kw, p_value_kw = stats.kruskal(l1_counts, l2_counts, l3_counts)

print(f"H-Statistik: {stat_kw:.4f}")
print(f"p-Wert:      {p_value_kw:.5e}\n")

if p_value_kw < 0.05:
    print(
        "-> Ergebnis: Signifikant! Mindestens eine der drei Gruppen unterscheidet sich signifikant von den anderen."
    )
    print("-> Gehe über zum Post-Hoc-Test, um die genauen Paare zu finden...\n")

    print("2. Dunn's Post-Hoc-Test (Paarweiser Vergleich)")

    # Dunn-Test berechnen (Bonferroni-Korrektur gegen Alpha-Fehler-Kumulierung)
    posthoc_matrix = sp.posthoc_dunn(
        df_experiment,
        val_col="annotation_count",
        group_col="complexity",
        p_adjust="bonferroni",
    )

    posthoc_matrix_rounded = posthoc_matrix.round(5)

    display(posthoc_matrix_rounded)

else:
    print(
        "-> Ergebnis: Nicht signifikant. Es gibt keine belegbaren Unterschiede zwischen den Gruppen."
    )
    print("-> Ein Post-Hoc-Test ist daher nicht zulässig/notwendig.")
# Out:
# 1. Kruskal-Wallis-Test (Globaler Unterschied)
# H-Statistik: 65.8597
# p-Wert:      4.99735e-15
#
# -> Ergebnis: Signifikant! Mindestens eine der drei Gruppen unterscheidet sich signifikant von den anderen.
# -> Gehe über zum Post-Hoc-Test, um die genauen Paare zu finden...
#
# 2. Dunn's Post-Hoc-Test (Paarweiser Vergleich)
#         L1      L2      L3
# L1  1.0000  0.0001  0.0000
# L2  0.0001  1.0000  0.0001
# L3  0.0000  0.0001  1.0000

# %% [markdown]
# Die Tabelle zeigt die p-Werte für jeden direkten Vergleich. Ist ein Wert kleiner als 0.05, ist der Unterschied zwischen diesen beiden Gruppen statistisch signifikant.
#
# Die Unterschiede zwischen allen drei Gruppen sind nach der Post-Hoc Analyse signifikant. Die statistische Evidenz stützt damit die Hypothese, dass die drei Stufen L1, L2 und L3 keine willkürliche Einteilung darstellen, sondern distinkte Anforderungsniveaus an das KI-System repräsentieren. Damit ist eine belastbare Grundlage geschaffen, um den Architekturvergleich (C1–C4) auf einer methodisch einwandfreien Basis durchzuführen.

# %% [markdown]
# ### Prüfung der relativen Informationsdichte

# %%
df_experiment["annotations_per_word"] = (
    df_experiment["annotation_count"] / df_experiment["word_count"]
)


l1_ratio = df_experiment[df_experiment["complexity"] == "L1"]["annotations_per_word"]
l2_ratio = df_experiment[df_experiment["complexity"] == "L2"]["annotations_per_word"]
l3_ratio = df_experiment[df_experiment["complexity"] == "L3"]["annotations_per_word"]

for name, group in [("L1", l1_ratio), ("L2", l2_ratio), ("L3", l3_ratio)]:
    stat, p = stats.shapiro(group)
    print(f"Shapiro-Wilk {name}: stat={stat:.4f}, p={p:.5f}")

stat_levene, p_levene = stats.levene(l1_ratio, l2_ratio, l3_ratio)
print(f"Levene-Test: stat={stat_levene:.4f}, p={p_levene:.5f}")
# Out:
# Shapiro-Wilk L1: stat=0.9494, p=0.24278
# Shapiro-Wilk L2: stat=0.8956, p=0.01473
# Shapiro-Wilk L3: stat=0.8665, p=0.00369
# Levene-Test: stat=1.0221, p=0.36500

# %% [markdown]
# Die Annahme der Normalverteilung ist verletzt (p<0,05) und die Anname der Varianzhomogenität ist ebenfalls nicht wahr, bewiesen durch den Levene-Test (p<0,05)

# %%
import seaborn as sns
from scipy import stats

stat_kw, p_value_kw = stats.kruskal(l1_ratio, l2_ratio, l3_ratio)

print("Kruskal-Wallis-Test für Annotations pro Wort:")
print(f"H-Statistik: {stat_kw:.4f}, p-Wert: {p_value_kw:.3f}")

# Post-Hoc-Test bei Signifikanz
if p_value_kw < 0.05:
    print("Ergebnis signifikant. Führe Dunn's Post-Hoc-Test durch...")
    posthoc = stats.posthoc_dunn(
        df_processed,
        val_col="annotations_per_word",
        group_col="complexity",
        p_adjust="bonferroni",
    )
    print(posthoc)
else:
    print("Ergebnis nicht signifikant. Kein Post-Hoc-Test erforderlich.")

# Plot
plt.figure(figsize=(8, 6))

df_processed["annotations_per_word"] = (
    df_processed["annotation_count"]
    .div(df_processed["word_count"].replace(0, np.nan))
)

sns.boxplot(
    data=df_processed,
    x="complexity",
    y="annotations_per_word",
    hue="complexity",
    palette=palette,
    order=["L1", "L2", "L3"],
    legend=False,
    boxprops={"alpha": 0.6},
    showfliers=False,
)

# Stripplot (Punkte im Vordergrund)
sns.stripplot(
    data=df_processed,
    x="complexity",
    y="annotations_per_word",
    hue="complexity",
    palette=palette,
    legend=False,
    jitter=True,
    alpha=0.8,
    size=5,
    linewidth=0.5,
    edgecolor="gray",
)

plt.title(
    f"Relative Informationsdichte (Annotations pro Wort)\nKruskal-Wallis-Test: H={stat_kw:.2f}, p={p_value_kw:.3f}",
    fontsize=14,
    fontweight="bold",
)
plt.ylabel("Ratio (Annotations / Words)", fontsize=12)
plt.xlabel("Komplexitätsstufe", fontsize=12)

plt.tight_layout()
plt.show()
# Out:
# Kruskal-Wallis-Test für Annotations pro Wort:
# H-Statistik: 4.1123, p-Wert: 0.128
# Ergebnis nicht signifikant. Kein Post-Hoc-Test erforderlich.
# /var/folders/6w/x9kzkbyn6r3_g6mbn02xl3740000gn/T/ipykernel_7228/2035581642.py:45: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(

# %% [markdown]
# Die Analyse zeigt, dass die absolute Anzahl an Annotationen signifikant mit der Komplexitätsstufe korreliert ($p < 0,001$). Im Gegensatz dazu ist die relative Informationsdichte (Annotationen pro Wort) über alle Stufen hinweg stabil (Kruskal-Wallis-Test: $H=3,45$, $p=0,178$; nicht signifikant).
# Heißt die Komplexität L3 ist primär durch eine erhöhte Datenmenge und nicht durch eine höhere semantische Dichte bedingt ist. Das validiert den Versuchsaufbau, weil KI-Modelle bei L3 somit nicht in einer höheren Informationsdichte, sondern mit irrelevanter Daten im Kontextfenster, verarbeiten müssen.

# %% [markdown]
# ### Prüfung der Anzahl von line_items pro Komplexität

# %%
def count_line_items(ground_truth: dict) -> int:
    """Zählt, wie viele Tabellenzeilen (line_items) ein Dokument hat.
    0, falls keine vorhanden."""
    if not isinstance(ground_truth, dict):
        return 0
    items = ground_truth.get("line_items", [])
    if isinstance(items, list):
        return len(items)
    return 0


df_experiment["line_item_rows"] = df_experiment["ground_truth"].apply(count_line_items)

# %%
df_experiment.groupby("complexity")["line_item_rows"].describe()
# Out:
#             count   mean        std   min   25%   50%   75%    max
# complexity
# L1           25.0   3.16   2.173323   0.0   1.0   3.0   4.0    8.0
# L2           25.0  11.92   4.319722   5.0   9.0  12.0  15.0   23.0
# L3           25.0  29.84  18.483506  11.0  22.0  27.0  31.0  110.0

# %% [markdown]
# Die Metrik line_item_rows validiert die Hypothese, dass die Komplexität maßgeblich durch die Skalierung der Aufgabenstellung (Extraktionsaufwand) getrieben wird. Die unterschiedliche Dichte an Tabellenzeilen bildet somit die ideale experimentelle Grundlage, um die Robustheit der verschiedenen KI-Architekturen (C1 bis C4) bei der Extraktion strukturierter Daten zu testen.

# %% [markdown]
# ### Erstellung des Korpus für Teilexperiment A

# %%
df_experiment.head(5)
# Out:
#                                        doc_id  \
# 43   0ea66228-6efd-8386-8000-e2e0c72e3825.pdf
# 284  63ad699d-fa76-17bb-1bc5-ab2fafd0a2a3.pdf
# 387  8ce03a7a-aa9c-da14-a16e-dabbec938595.pdf
# 448  a5b12494-83b6-c5c0-1e0f-0826f37899f0.pdf
# 631  faa55a77-9090-22ac-fe9b-32ab3f026300.pdf
#
#                                  property  has_line_items  \
# 43   REMIT TO Sinclair Broadcast c/o WTTO            True
# 284                       WPNT Pittsburgh            True
# 387                             KMEG KMEG            True
# 448     Denver KDVR KDVR Denver KDVR KDVR            True
# 631                               UNKNOWN            True
#
#                                           ground_truth  \
# 43   {'advertiser': 'Friends of Jeff Sessions Senat...
# 284  {'contract_num': '4339717', 'flight_from': '05...
# 387  {'property': 'KMEG KMEG', 'contract_num': '135...
# 448  {'property': 'Denver KDVR KDVR Denver KDVR KDV...
# 631  {'contract_num': '26932832', 'flight_to': '6/8...
#
#                                                raw_doc  \
# 43   {'filename': '0ea66228-6efd-8386-8000-e2e0c72e...
# 284  {'filename': '63ad699d-fa76-17bb-1bc5-ab2fafd0...
# 387  {'filename': '8ce03a7a-aa9c-da14-a16e-dabbec93...
# 448  {'filename': 'a5b12494-83b6-c5c0-1e0f-0826f378...
# 631  {'filename': 'faa55a77-9090-22ac-fe9b-32ab3f02...
#
#                                            annotations  \
# 43   [[advertiser, [['Friends of Jeff Sessions Sena...
# 284  [[contract_num, [['4339717\n', [0, 0.36060825,...
# 387  [[property, [['KMEG\n', [0, 0.6221532200000001...
# 448  [[property, [['Denver KDVR\n', [0, 0.148639220...
# 631  [[contract_num, [['26932832\n', [0, 0.34807149...
#
#                                               ocr_text  annotation_count  \
# 43   REMIT TO Sinclair Broadcast c/o WTTO PO Box 20...                12
# 284  Contract # Date Entered 04/15/20 Spots Schedul...                12
# 387  Page 1 of 1 KMEG KMEG 100 Gold Circle Dr Dakot...                11
# 448  Page 1 of 2 INVOICE FOX 31 Remit Address: Denv...                17
# 631  Contract # 26932832 CPE: //1447 Agency: AL MED...                10
#
#     complexity  word_count  char_count  annotations_per_word  line_item_rows
# 43          L1         300        2068              0.040000               5
# 284         L1         294        1958              0.040816               3
# 387         L1         339        2113              0.032448               2
# 448         L1         483        2984              0.035197               4
# 631         L1         195        1166              0.051282               1
